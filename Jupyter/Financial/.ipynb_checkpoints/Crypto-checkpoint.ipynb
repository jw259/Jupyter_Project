# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
from pandas_datareader import data
import numpy as np
import seaborn as sns
from datetime import date

# %%
tickers = ['FB', 'AAPL', 'AMZN', 'NFLX', 'GOOG', 'MSFT', 'QCOM', 'NVDA', 'ZM']

start_date = '1980-12-12'
end_date = date.today()

#web.DataReader("AAPL", "av-daily", start=datetime(2017, 2, 9),
financial_data = data.DataReader(tickers, 'av-daily', start_date, end_date, api_key = '2DJLDZS451IHB7WJ')

# %%
financial_data.head(-1)
# Out:
#                 open      high      low   close    volume
# 2019-04-18   65.0000   66.0000   60.321   62.00  25764659
# 2019-04-22   61.0000   68.9000   59.940   65.70   9949738
# 2019-04-23   66.8700   74.1690   65.550   69.00   6786513
# 2019-04-24   71.4000   71.5000   63.160   63.20   4973529
# 2019-04-25   64.7400   66.8500   62.600   65.00   3863275
# ...              ...       ...      ...     ...       ...
# 2020-10-20  572.3300  575.6900  534.590  537.02  12098179
# 2020-10-21  535.8800  551.6600  511.780  513.19   9215428
# 2020-10-22  521.7800  530.4299  503.470  520.54   8100869
# 2020-10-23  522.3300  526.9999  505.410  511.52   5377118
# 2020-10-26  520.4885  541.1050  510.310  517.79  10080795
#
# [385 rows x 5 columns]

# %%
close_data = financial_data['Close']
close_data.head(-1)
# Out:
# Symbols             FB        AAPL         AMZN        NFLX         GOOG  \
# Date
# 1980-12-12         NaN    0.128348          NaN         NaN          NaN
# 1980-12-15         NaN    0.121652          NaN         NaN          NaN
# 1980-12-16         NaN    0.112723          NaN         NaN          NaN
# 1980-12-17         NaN    0.115513          NaN         NaN          NaN
# 1980-12-18         NaN    0.118862          NaN         NaN          NaN
# ...                ...         ...          ...         ...          ...
# 2020-10-20  267.559998  117.510002  3217.010010  525.419983  1555.930054
# 2020-10-21  278.730011  116.870003  3184.939941  489.049988  1593.310059
# 2020-10-22  278.119995  115.750000  3176.399902  485.230011  1615.329956
# 2020-10-23  284.790009  115.040001  3204.399902  488.279999  1641.000000
# 2020-10-26  277.109985  115.050003  3207.040039  488.239990  1590.449951
#
# Symbols           MSFT        QCOM        NVDA          ZM
# Date
# ...

# %%
close_data.describe()
# Out:
# Symbols           FB          AAPL         AMZN         NFLX         GOOG  \
# count    2125.000000  10054.000000  5903.000000  4641.000000  4077.000000
# mean      120.940183      9.432440   402.138600    83.576173   537.343589
# std        65.106746     18.095140   649.855302   127.149057   389.955157
# min        17.730000      0.049107     1.395833     0.372857    49.818268
# 25%        68.830002      0.270714    38.109999     3.818571   240.418854
# 50%       119.239998      0.440848    84.500000    15.962857   344.802582
# 75%       175.039993     11.023393   373.554993   100.720001   775.419983
# max       303.910004    134.179993  3531.449951   556.549988  1728.280029
#
# Symbols         MSFT         QCOM         NVDA          ZM
# count    8729.000000  7273.000000  5478.000000  386.000000
# mean       31.976725    37.312609    52.459344  160.344972
# std        37.421147    26.521335    90.528755  124.702122
# min         0.090278     0.410156     1.364583   62.000000
# ...

# %%
returns_data = close_data.pct_change()
returns_data.head(-1)
# Out:
# Symbols           FB      AAPL      AMZN      NFLX      GOOG      MSFT  \
# Date
# 1980-12-12       NaN       NaN       NaN       NaN       NaN       NaN
# 1980-12-15       NaN -0.052174       NaN       NaN       NaN       NaN
# 1980-12-16       NaN -0.073394       NaN       NaN       NaN       NaN
# 1980-12-17       NaN  0.024752       NaN       NaN       NaN       NaN
# 1980-12-18       NaN  0.028986       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2020-10-20  0.023565  0.013192  0.003056 -0.009986  0.013893  0.002007
# 2020-10-21  0.041748 -0.005446 -0.009969 -0.069221  0.024024  0.000699
# 2020-10-22 -0.002189 -0.009583 -0.002681 -0.007811  0.013820  0.000419
# 2020-10-23  0.023983 -0.006134  0.008815  0.006286  0.015892  0.006236
# 2020-10-26 -0.026967  0.000087  0.000824 -0.000082 -0.030804 -0.028442
#
# Symbols         QCOM      NVDA        ZM
# Date
# 1980-12-12       NaN       NaN       NaN
# ...

# %%
mean = returns_data.mean() * 100
print(mean)
# Out:
# Symbols
# FB      0.121403
# AAPL    0.109643
# AMZN    0.193117
# NFLX    0.195437
# GOOG    0.103336
# MSFT    0.111432
# QCOM    0.122856
# NVDA    0.179727
# ZM      0.663991
# dtype: float64

# %%
std = returns_data.std() * 100
print(std)
# Out:
# Symbols
# FB      2.354989
# AAPL    2.868354
# AMZN    3.708789
# NFLX    3.625739
# GOOG    1.927970
# MSFT    2.154151
# QCOM    3.136092
# NVDA    3.863229
# ZM      4.750807
# dtype: float64

# %%
returns_data.describe()
# Out:
# Symbols           FB          AAPL         AMZN         NFLX         GOOG  \
# count    2124.000000  10053.000000  5902.000000  4640.000000  4076.000000
# mean        0.001214      0.001096     0.001931     0.001954     0.001033
# std         0.023550      0.028684     0.037088     0.036257     0.019280
# min        -0.189609     -0.518692    -0.247661    -0.409065    -0.116091
# 25%        -0.009172     -0.013274    -0.013319    -0.014456    -0.007378
# 50%         0.001081      0.000000     0.000487     0.000303     0.000684
# 75%         0.012106      0.014815     0.015113     0.017413     0.010025
# max         0.296115      0.332278     0.344714     0.422235     0.199915
#
# Symbols         MSFT         QCOM         NVDA          ZM
# count    8728.000000  7272.000000  5477.000000  385.000000
# mean        0.001114     0.001229     0.001797    0.006640
# std         0.021542     0.031361     0.038632    0.047508
# min        -0.301158    -0.168478    -0.352335   -0.152795
# ...

# %%
#norm_data = close_data / (close_data.max(axis=0) + np.spacing(0)) * 100
norm_data = close_data

fb = norm_data.loc[:, 'FB']
aapl = norm_data.loc[:, 'AAPL']
amzn = norm_data.loc[:, 'AMZN']
nflx = norm_data.loc[:, 'NFLX']
goog = norm_data.loc[:, 'GOOG']
msft = norm_data.loc[:, 'MSFT']
qcom = norm_data.loc[:, 'QCOM']
nvda = norm_data.loc[:, 'NVDA']
zm = norm_data.loc[:, 'ZM']

fig, ax = plt.subplots(figsize=(16,20))
ax.plot(fb.index, fb, label='Facebook', color='royalblue')
ax.plot(aapl.index, aapl, label='Apple', color='dimgrey')
ax.plot(amzn.index, amzn, label='Amazon', color='darkorange')
ax.plot(nflx.index, nflx, label='Netflix', color='crimson')
ax.plot(goog.index, goog, label='Google', color='deeppink')
ax.plot(msft.index, msft, label='Microsoft', color='darkorchid')
ax.plot(qcom.index, qcom, label='Qualcomm', color='blue')
ax.plot(nvda.index, nvda, label='Nvidia', color='limegreen')
ax.plot(zm.index, zm, label='Zoom', color='dodgerblue')
ax.set_ylabel('Value')
ax.set_xlabel('Time')
ax.yaxis.set_major_locator(MultipleLocator(1000))
ax.yaxis.set_minor_locator(MultipleLocator(500))
ax.grid(b=True, which='major', axis='both', color='0.5', linestyle='--', linewidth=1)
ax.grid(b=True, which='minor', axis='both', color='0.6', linestyle=':', linewidth=0.75)
ax.set_xlim((datetime.date(1997, 1, 1), date.today()))
ax.set_ylim((0, 3500))
# Out:
# (0, 100)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import metrics

threshold = 0.15

drop_data = returns_data['AMZN'].dropna()

reindex_data = drop_data.reset_index()

del reindex_data['Date']

reindex_data.loc[reindex_data['AMZN'] >= threshold, 'CLASS'] = 1
reindex_data.loc[reindex_data['AMZN'] < threshold, 'CLASS'] = 0

X = reindex_data[['AMZN']].values
y = reindex_data['CLASS']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=4)


# Decision tree

tree = DecisionTreeClassifier(criterion="entropy", max_depth = None)
tree
tree.fit(X_train,y_train)

yhat = tree.predict(X_test)

print("Decision Tree Accuracy: ", metrics.accuracy_score(y_test, yhat))
print("Decision Tree MSE: ", metrics.mean_squared_error(y_test, yhat))
print("Decision Tree F1 Score: ", metrics.f1_score(y_test, yhat, average='weighted'))
print("Decision Tree Jaccard Similarity Score: ", metrics.jaccard_similarity_score(y_test, yhat))


# K Nearest Neighbor

k = 16
neigh = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)

yhat = neigh.predict(X_test)

print("kNN Accuracy: ", metrics.accuracy_score(y_test, yhat))
print("kNN MSE: ", metrics.mean_squared_error(y_test, yhat))
print("kNN F1 Score: ", metrics.f1_score(y_test, yhat, average='weighted'))
print("kNN Jaccard Similarity Score: ", metrics.jaccard_similarity_score(y_test, yhat))

# Finding and plotting the best value for k

Ks = 1
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))
ConfustionMx = [];

for n in range(1,Ks):  
    neigh = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train)
    yhat=neigh.predict(X_test)
    mean_acc[n-1] = metrics.accuracy_score(y_test, yhat)
    std_acc[n-1]=np.std(yhat==y_test)/np.sqrt(yhat.shape[0])

plt.plot(range(1,Ks),mean_acc,'g')
plt.fill_between(range(1,Ks),mean_acc - 1 * std_acc,mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy')
plt.xlabel('Number of Neighbors (K)')
plt.tight_layout()
plt.show()

# Logistic Regression

log = LogisticRegression(C=0.01, solver='liblinear').fit(X_train,y_train)

yhat = log.predict(X_test)

print("Logistic Regression Accuracy: ", metrics.accuracy_score(y_test, yhat))
print("Logistic Regression MSE: ", metrics.mean_squared_error(y_test, yhat))
print("Logistic Regression F1 Score: ", metrics.f1_score(y_test, yhat, average='weighted'))
print("Logistic Regression Jaccard Similarity Score: ", metrics.jaccard_similarity_score(y_test, yhat))
print("Logistic Regression Log Loss: ", metrics.log_loss(y_test, yhat))

# Support Vector Machine

clf = svm.SVC(kernel='rbf')
clf.fit(X_train, y_train)
yhat = clf.predict(X_test)

print("SVM Accuracy: ", metrics.accuracy_score(y_test, yhat))
print("SVM MSE: ", metrics.mean_squared_error(y_test, yhat))
print("SVM F1 Score: ", metrics.f1_score(y_test, yhat, average='weighted'))
print("SVM Jaccard Similarity Score: ", metrics.jaccard_similarity_score(y_test, yhat))
# Out:
# Date
# 1980-12-15   -0.052174
# 1980-12-16   -0.073394
# 1980-12-17    0.024752
# 1980-12-18    0.028986
# 1980-12-19    0.061033
#                 ...
# 2020-10-21   -0.005446
# 2020-10-22   -0.009583
# 2020-10-23   -0.006134
# 2020-10-26    0.000087
# 2020-10-27    0.013342
# Name: AAPL, Length: 10053, dtype: float64
#            AAPL
# 0     -0.052174
# 1     -0.073394
# 2      0.024752
# 3      0.028986
# 4      0.061033
# ...         ...
# 10048 -0.005446
# 10049 -0.009583
# 10050 -0.006134
# 10051  0.000087
# 10052  0.013342
#
# [10053 rows x 1 columns]
#            AAPL  CLASS
# 0     -0.052174    0.0
# 1     -0.073394    0.0
# 2      0.024752    1.0
# 3      0.028986    1.0
# 4      0.061033    1.0
# ...         ...    ...
# 10048 -0.005446    0.0
# 10049 -0.009583    0.0
# 10050 -0.006134    0.0
# 10051  0.000087    1.0
# 10052  0.013342    1.0
#
# [10053 rows x 2 columns]
# 4643    0.069767
# 5467   -0.000667
# 9614    0.000481
# 8781    0.023927
# 7802   -0.010442
# ...
