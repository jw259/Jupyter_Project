# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/JulianWithoeft/opt/anaconda3/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['std', 'clf', 'mean']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
import pandas as pd
from pandas_datareader import data
import numpy as np
import seaborn as sns
from datetime import date

# %%
tickers = ['FB', 'AAPL', 'AMZN', 'NFLX', 'GOOG', 'MSFT', 'QCOM', 'NVDA', 'ZM']

start_date = '1972-01-01'
end_date = date.today()

financial_data = data.DataReader(tickers, 'yahoo', start_date, end_date)

# %%
financial_data.head(-1)
# Out:
# Attributes   Adj Close                                                    \
# Symbols             FB        AAPL         AMZN        NFLX         GOOG
# Date
# 1980-12-12         NaN    0.101261          NaN         NaN          NaN
# 1980-12-15         NaN    0.095978          NaN         NaN          NaN
# 1980-12-16         NaN    0.088934          NaN         NaN          NaN
# 1980-12-17         NaN    0.091135          NaN         NaN          NaN
# 1980-12-18         NaN    0.093777          NaN         NaN          NaN
# ...                ...         ...          ...         ...          ...
# 2020-10-20  267.559998  117.510002  3217.010010  525.419983  1555.930054
# 2020-10-21  278.730011  116.870003  3184.939941  489.049988  1593.310059
# 2020-10-22  278.119995  115.750000  3176.399902  485.230011  1615.329956
# 2020-10-23  284.790009  115.040001  3204.399902  488.279999  1641.000000
# 2020-10-26  277.109985  115.050003  3207.040039  488.239990  1590.449951
#
# Attributes                                                       Close  ...  \
# Symbols           MSFT        QCOM        NVDA          ZM          FB  ...
# Date                                                                    ...
# 1980-12-12         NaN         NaN         NaN         NaN         NaN  ...
# 1980-12-15         NaN         NaN         NaN         NaN         NaN  ...
# 1980-12-16         NaN         NaN         NaN         NaN         NaN  ...
# 1980-12-17         NaN         NaN         NaN         NaN         NaN  ...
# 1980-12-18         NaN         NaN         NaN         NaN         NaN  ...
# ...                ...         ...         ...         ...         ...  ...
# 2020-10-20  214.649994  128.300003  545.820007  537.020020  267.559998  ...
# 2020-10-21  214.800003  128.550003  540.989990  513.190002  278.730011  ...
# 2020-10-22  214.889999  128.380005  534.440002  520.539978  278.119995  ...
# 2020-10-23  216.229996  128.880005  543.609985  511.519989  284.790009  ...
# 2020-10-26  210.080002  126.199997  525.650024  517.789978  277.109985  ...
#
# Attributes        Open      Volume                                      \
# Symbols             ZM          FB         AAPL       AMZN        NFLX
# Date
# 1980-12-12         NaN         NaN  469033600.0        NaN         NaN
# 1980-12-15         NaN         NaN  175884800.0        NaN         NaN
# 1980-12-16         NaN         NaN  105728000.0        NaN         NaN
# 1980-12-17         NaN         NaN   86441600.0        NaN         NaN
# 1980-12-18         NaN         NaN   73449600.0        NaN         NaN
# ...                ...         ...          ...        ...         ...
# 2020-10-20  572.330017  18763200.0  124423700.0  4509700.0  10047200.0
# 2020-10-21  535.880005  28998600.0   89946000.0  4592700.0  17405700.0
# 2020-10-22  521.780029  16720000.0  101988000.0  4212000.0   6997900.0
# 2020-10-23  522.330017  17535200.0   82572600.0  3466700.0   4927900.0
# 2020-10-26  520.489014  21296800.0  109982600.0  5851500.0   6174200.0
#
# Attributes
# Symbols          GOOG        MSFT       QCOM       NVDA          ZM
# Date
# 1980-12-12        NaN         NaN        NaN        NaN         NaN
# 1980-12-15        NaN         NaN        NaN        NaN         NaN
# 1980-12-16        NaN         NaN        NaN        NaN         NaN
# 1980-12-17        NaN         NaN        NaN        NaN         NaN
# 1980-12-18        NaN         NaN        NaN        NaN         NaN
# ...               ...         ...        ...        ...         ...
# 2020-10-20  2241700.0  22753500.0  4409800.0  5730300.0  12098200.0
# 2020-10-21  2568300.0  22724900.0  4344000.0  5489900.0   9215400.0
# 2020-10-22  1433600.0  22351500.0  3895100.0  7262000.0   8100900.0
# 2020-10-23  1375800.0  18879600.0  3943100.0  5837100.0   5377100.0
# 2020-10-26  1851700.0  36482200.0  6048200.0  8400400.0  10036900.0
#
# [10053 rows x 54 columns]

# %%
close_data = financial_data['Close']
close_data.head(-1)
# Out:
# Symbols             FB        AAPL         AMZN        NFLX         GOOG  \
# Date
# 1990-01-02         NaN    0.332589          NaN         NaN          NaN
# 1990-01-03         NaN    0.334821          NaN         NaN          NaN
# 1990-01-04         NaN    0.335938          NaN         NaN          NaN
# 1990-01-05         NaN    0.337054          NaN         NaN          NaN
# 1990-01-08         NaN    0.339286          NaN         NaN          NaN
# ...                ...         ...          ...         ...          ...
# 2020-10-19  261.399994  115.980003  3207.209961  530.719971  1534.609985
# 2020-10-20  267.559998  117.510002  3217.010010  525.419983  1555.930054
# 2020-10-21  278.730011  116.870003  3184.939941  489.049988  1593.310059
# 2020-10-22  278.119995  115.750000  3176.399902  485.230011  1615.329956
# 2020-10-23  284.790009  115.040001  3204.399902  488.279999  1641.000000
#
# Symbols           MSFT        QCOM        NVDA          ZM
# Date
# 1990-01-02    0.616319         NaN         NaN         NaN
# 1990-01-03    0.619792         NaN         NaN         NaN
# 1990-01-04    0.638021         NaN         NaN         NaN
# 1990-01-05    0.622396         NaN         NaN         NaN
# 1990-01-08    0.631944         NaN         NaN         NaN
# ...                ...         ...         ...         ...
# 2020-10-19  214.220001  128.419998  539.909973  568.340027
# 2020-10-20  214.649994  128.300003  545.820007  537.020020
# 2020-10-21  214.800003  128.550003  540.989990  513.190002
# 2020-10-22  214.889999  128.380005  534.440002  520.539978
# 2020-10-23  216.229996  128.880005  543.609985  511.519989
#
# [7765 rows x 9 columns]

# %%
returns_data = close_data.pct_change()
returns_data.head(-1)
# Out:
# Symbols           FB      AAPL      AMZN      NFLX      GOOG      MSFT  \
# Date
# 1990-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-01-03       NaN  0.006711       NaN       NaN       NaN  0.005634
# 1990-01-04       NaN  0.003333       NaN       NaN       NaN  0.029412
# 1990-01-05       NaN  0.003322       NaN       NaN       NaN -0.024490
# 1990-01-08       NaN  0.006622       NaN       NaN       NaN  0.015342
# ...              ...       ...       ...       ...       ...       ...
# 2020-10-19 -0.017035 -0.025542 -0.020014 -0.000132 -0.024412 -0.024766
# 2020-10-20  0.023565  0.013192  0.003056 -0.009986  0.013893  0.002007
# 2020-10-21  0.041748 -0.005446 -0.009969 -0.069221  0.024024  0.000699
# 2020-10-22 -0.002189 -0.009583 -0.002681 -0.007811  0.013820  0.000419
# 2020-10-23  0.023983 -0.006134  0.008815  0.006286  0.015892  0.006236
#
# Symbols         QCOM      NVDA        ZM
# Date
# 1990-01-02       NaN       NaN       NaN
# 1990-01-03       NaN       NaN       NaN
# 1990-01-04       NaN       NaN       NaN
# 1990-01-05       NaN       NaN       NaN
# 1990-01-08       NaN       NaN       NaN
# ...              ...       ...       ...
# 2020-10-19 -0.004728 -0.022717  0.016708
# 2020-10-20 -0.000934  0.010946 -0.055108
# 2020-10-21  0.001949 -0.008849 -0.044375
# 2020-10-22 -0.001322 -0.012107  0.014322
# 2020-10-23  0.003895  0.017158 -0.017328
#
# [7765 rows x 9 columns]

# %%
mean = returns_data.mean() * 100
print(mean)
# Out:
# Symbols
# FB      0.120761
# AAPL    0.114808
# AMZN    0.192916
# NFLX    0.195695
# GOOG    0.103369
# MSFT    0.095617
# QCOM    0.122881
# NVDA    0.179526
# ZM      0.661433
# dtype: float64

# %%
std = returns_data.std() * 100
print(std)

# %%
returns_data.describe()
# Out:
# Symbols           FB         AAPL         AMZN         NFLX         GOOG  \
# count    2123.000000  7765.000000  5901.000000  4639.000000  4075.000000
# mean        0.001208     0.001148     0.001929     0.001957     0.001034
# std         0.023554     0.027822     0.037091     0.036261     0.019282
# min        -0.189609    -0.518692    -0.247661    -0.409065    -0.116091
# 25%        -0.009182    -0.012317    -0.013322    -0.014458    -0.007381
# 50%         0.001077     0.000271     0.000486     0.000306     0.000686
# 75%         0.012086     0.014218     0.015114     0.017417     0.010025
# max         0.296115     0.332278     0.344714     0.422235     0.199915
#
# Symbols         MSFT         QCOM         NVDA          ZM
# count    7765.000000  7271.000000  5476.000000  384.000000
# mean        0.000956     0.001229     0.001795    0.006614
# std         0.020267     0.031363     0.038636    0.047567
# min        -0.155978    -0.168478    -0.352335   -0.152795
# 25%        -0.009115    -0.012958    -0.016294   -0.016442
# 50%         0.000351     0.000000     0.000862    0.003815
# 75%         0.010690     0.014232     0.017660    0.024708
# max         0.195652     0.387111     0.424145    0.407844

# %%
msft = close_data.loc[:, 'MSFT']
fig, ax = plt.subplots(figsize=(16,9))
sns.lineplot(data=close_data, x="msft.index", y="msft", ax=axes[0,0])
#ax.plot(msft.index, msft, label='MSFT')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-117-cc18686e30f5> in <module>
#       2 fig, ax = plt.subplots(figsize=(16,9))
#       3 #sns.lineplot(data=close_data, x="msft.index", y="msft", ax=axes[0,0])
# ----> 4 sns.lineplot(data=close_data, x="Date", y="MSFT", ax=axes[0,0])
#       5 #ax.plot(msft.index, msft, label='MSFT')
#
# TypeError: 'function' object is not subscriptable

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn import metrics

threshold = 0.2

drop_data = returns_data['AAPL'].dropna()

drop_data.loc[returns_data['AAPL'] >= threshold, 'CLASS'] = 1
drop_data.loc[returns_data['AAPL'] < threshold, 'CLASS'] = 0

x = drop_data['AAPL']
y = drop_data['CLASS']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=4)

clf =svm.SVC(kernel='rbf')
clf.fit(x_train, y_train)

yhat = clf.predict(x_test)

print("SVM Accuracy: ", metrics.accuracy_score(y_test, yhat))
print("SVM MSE: ", metrics.mean_squared_error(y_test, yhat))
print("SVM F1 Score: ", metrics.f1_score(y_test, yhat, average='weighted'))
print("SVM Jaccard Similarity Score: ", metrics.jaccard_similarity_score(y_test, yhat))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_setitem_indexer(self, key)
#     655         try:
# --> 656             return self._convert_to_indexer(key, axis=axis)
#     657         except TypeError as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, raise_missing)
#    1730                 # When setting, missing keys are not allowed, even with .loc:
# -> 1731                 return self._get_listlike_indexer(obj, axis, raise_missing=True)[1]
#    1732         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1545                 key = self._convert_for_reindex(key, axis)
# -> 1546             indexer = ax.get_indexer_for(key)
#    1547             keyarr = ax.reindex(keyarr)[0]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_indexer_for(self, target, **kwargs)
#    4501         if self.is_unique:
# -> 4502             return self.get_indexer(target, **kwargs)
#    4503         indexer, _ = self.get_indexer_non_unique(target, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    2728             return this.get_indexer(
# -> 2729                 target, method=method, limit=limit, tolerance=tolerance
#    2730             )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    2752
# -> 2753             indexer = self._engine.get_indexer(target._ndarray_values)
#    2754
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_indexer()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __hash__(self)
#    1798         raise TypeError(
# -> 1799             f"{repr(type(self).__name__)} objects are mutable, "
#    1800             f"thus they cannot be hashed"
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
#
# During handling of the above exception, another exception occurred:
#
# IndexingError                             Traceback (most recent call last)
# <ipython-input-126-03ab64f620e4> in <module>
#       7 drop_data = returns_data['AAPL'].dropna()
#       8
# ----> 9 drop_data.loc[returns_data['AAPL'] >= threshold, 'CLASS'] = 1
#      10 drop_data.loc[returns_data['AAPL'] < threshold, 'CLASS'] = 0
#      11
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     667         else:
#     668             key = com.apply_if_callable(key, self.obj)
# --> 669         indexer = self._get_setitem_indexer(key)
#     670         self._setitem_with_indexer(indexer, value)
#     671
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_setitem_indexer(self, key)
#     660             if "cannot do" in str(e):
#     661                 raise
# --> 662             raise IndexingError(key)
#     663
#     664     def __setitem__(self, key, value):
#
# IndexingError: (Date
# 1990-01-02    False
# 1990-01-03    False
# 1990-01-04    False
# 1990-01-05    False
# 1990-01-08    False
#               ...
# 2020-10-20    False
# 2020-10-21    False
# 2020-10-22    False
# 2020-10-23    False
# 2020-10-26    False
# Name: AAPL, Length: 7766, dtype: bool, 'CLASS')
